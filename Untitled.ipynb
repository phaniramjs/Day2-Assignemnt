# %% [markdown]
# # Assignment Day 2 | 9th November 2020

# %% [markdown]
# ### Questions 1: Create an empty list. Accept 10 numbers from the user and append to it the list if it is an even number

# %%
list1=[]
for i in range(0,10):
    n=int(input("Enter a Numbner"))
    if(n%2==0):
        list1.append(n)
print(list1)
# Out:
# Enter a Numbner 1
# Enter a Numbner 2
# Enter a Numbner 3
# Enter a Numbner 4
# Enter a Numbner 5
# Enter a Numbner 6
# Enter a Numbner 7
# Enter a Numbner 8
# Enter a Numbner 9
# Enter a Numbner 10
# [2, 4, 6, 8, 10]

# %% [markdown]
# ### Questions 2:Create a notebook on LIST COMPREHENSION. This exercise is to put you in a Self learning mode

# %%
#i would like to read list of string integers and convert them into int
list1=input("Enter 1 to 10 numbers ").split()
print("Before ",list1)
list2=[int(i) for i in list1]
print("After ",list2)

languages=["python","java","perl",'Ruby','Java Script','python Script']
lang_starts_with_p=[]
[lang_starts_with_p.append(i) for i in languages if(i.startswith('p'))]
print(lang_starts_with_p)
# Out:
# Enter 1 to 10 numbers  5 1 2 3 4 10 9 8 7 6
# Before  ['5', '1', '2', '3', '4', '10', '9', '8', '7', '6']
# After  [5, 1, 2, 3, 4, 10, 9, 8, 7, 6]
# ['python', 'perl', 'python Script']

# %% [markdown]
# ### Questions 3: You have seen in the videos how powerful dictionary data structure is. In this assignment, given a number n, you have to write a program that generates a dictionary d which contains (i, i*i), where i is from 1 to n (both included). Then you have to just print this dictionary d.

# %%
dict1={}
n=int(input("Enter a Number"))
for i in range(1,n+1):
    dict1[i]=i*i
print(dict1)
# Out:
# Enter a Number 10
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
import math

pos = {"x": 0,"y": 0}
while True:

    n = input()
    if not n:
        break

    direction,steps=n.split()
    if direction == "UP":
        pos["y"] += int(steps)
    elif direction == "DOWN":
        pos["y"] -= int(steps)
    elif direction == "LEFT":
        pos["x"] -= int(steps)
    elif direction == "RIGHT":
        pos["x"] += int(steps)
print (int(round((pos["x"]**2 + pos["y"]**2)**0.5)))
